# %% [markdown]
# # 📊 Student Grades Analysis
#
# In this notebook, we will analyze the performance of students in various subjects for Semester 2.
# We'll explore grade distributions, correlations, student profiles, and attempt simple clustering.

# %%
import pandas as pd
df = pd.read_csv("examencleanv2.csv")

# %% [markdown]
# ## 📖 Dataset Overview
#
# Let’s start by exploring what this dataset contains:
# - Number of students
# - Number of subjects
# - Overview of the grades (min, max, mean, std)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 17 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Unnamed: 0                                       108 non-null    int64
#  1   0                                                108 non-null    int64
#  2   Student_ID                                       108 non-null    int64
#  3   Last_Name                                        108 non-null    object
#  4   First_Name                                       108 non-null    object
#  5   Proba_Stat                                       108 non-null    float64
#  6   Analyse_Numerique                                108 non-null    float64
#  7   Structure_Donnee                                 108 non-null    float64
#  8   C++                                              108 non-null    float64
# ...

# %%
df.drop(["Student_ID", "Last_Name", "First_Name"], axis=1).describe()
# Out:
#        Unnamed: 0          0  Proba_Stat  Analyse_Numerique  Structure_Donnee  \
# count   108.00000  108.00000  108.000000         108.000000        108.000000
# mean     53.50000   54.50000    9.842593           9.597222          9.546296
# std      31.32092   31.32092    3.478672           4.575411          3.602496
# min       0.00000    1.00000    0.000000           0.000000          0.000000
# 25%      26.75000   27.75000    8.250000           6.937500          7.500000
# 50%      53.50000   54.50000   10.250000          10.000000          9.750000
# 75%      80.25000   81.25000   12.250000          12.562500         12.500000
# max     107.00000  108.00000   16.500000          18.000000         17.000000
#
#              C++  Architecture_des_systèmes_à_Microprocesseu  \
# count  108.00000                                  108.000000
# mean    13.12037                                   10.034722
# std      4.27767                                    4.440476
# ...

# %% [markdown]
# ## 📈 Grade Distribution per Subject
#
# We’ll visualize the distribution of grades for each subject to:
# - Identify subjects with high or low average scores
# - Detect outliers
# - See how grades are spread (are they normal, skewed, etc.)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Proba_Stat = df['Proba_Stat'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=Proba_Stat.index, y=Proba_Stat.values,)
plt.xlabel("Proba_Stat")
plt.ylabel("Count")
plt.title("Distribution of Individual Proba_Stat Grades")
plt.xticks(rotation=45)
plt.show()

# %%
Analyse_Numerique = df['Analyse_Numerique'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=Analyse_Numerique.index, y=Analyse_Numerique.values,)
plt.xlabel("Analyse_Numerique")
plt.ylabel("Count")
plt.title("Distribution of Individual Analyse_Numerique Grades")
plt.xticks(rotation=45)
plt.show()

# %%
Structure_Donnee = df['Structure_Donnee'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=Structure_Donnee.index, y=Structure_Donnee.values,)
plt.xlabel("Structure_Donnee")
plt.ylabel("Count")
plt.title("Distribution of Individual Structure_Donnee Grades")
plt.xticks(rotation=45)
plt.show()

# %%
POO = df['C++'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=POO.index, y=POO.values,)
plt.xlabel("C++")
plt.ylabel("Count")
plt.title("Distribution of Individual C++ Grades")
plt.xticks(rotation=45)
plt.show()

# %%
ARM = df['Architecture_des_systèmes_à_Microprocesseu'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=ARM.index, y=ARM.values,)
plt.xlabel("Architecture_des_systèmes_à_Microprocesseur")
plt.ylabel("Count")
plt.title("Distribution of Individual Architecture_des_systèmes_à_Microprocesseur Grades")
plt.xticks(rotation=45)
plt.show()

# %%
rsx = df['Fondement_des_réseau'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=rsx.index, y=rsx.values,)
plt.xlabel("Fondement_des_réseaux")
plt.ylabel("Count")
plt.title("Distribution of Individual Fondement_des_réseaux Grades")
plt.xticks(rotation=45)
plt.show()

# %%
web = df['Technologies_Web '].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=web.index, y=web.values,)
plt.xlabel("Technologies_Web")
plt.ylabel("Count")
plt.title("Distribution of Individual Technologies_Web Grades")
plt.xticks(rotation=45)
plt.show()

# %%
bd = df['Base_de_Données'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=bd.index, y=bd.values,)
plt.xlabel("Base_de_Données")
plt.ylabel("Count")
plt.title("Distribution of Individual Base_de_Données Grades")
plt.xticks(rotation=45)
plt.show()

# %%
UML = df['Analyse_et_conception_des_Systèmes_dInformation'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=UML.index, y=UML.values,)
plt.xlabel("Analyse_et_conception_des_Systèmes_d'Information")
plt.ylabel("Count")
plt.title("Distribution of Individual Analyse_et_conception_des_Systèmes_d'Informations Grades")
plt.xticks(rotation=45)
plt.show()

# %%
eco = df['Théorie_des_Organisations'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=eco.index, y=eco.values,)
plt.xlabel("Théorie_des_Organisations")
plt.ylabel("Count")
plt.title("Distribution of Individual Théorie_des_Organisations Grades")
plt.xticks(rotation=45)
plt.show()

# %%
ang = df['Professional_English'].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=ang.index, y=ang.values,)
plt.xlabel("Professional_English")
plt.ylabel("Count")
plt.title("Distribution of Individual Professional_English Grades")
plt.xticks(rotation=45)
plt.show()

# %%
fr = df['Culture_et_Communication '].value_counts().sort_index()
plt.figure(figsize=(16,6))
sns.barplot(x=fr.index, y=fr.values,)
plt.xlabel("Culture_et_Communication")
plt.ylabel("Count")
plt.title("Distribution of Individual Culture_et_Communication Grades")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 🔥 Correlation Analysis
#
# We’ll check how grades in different subjects relate to each other.
# Questions we’ll answer:
# - Do students who perform well in Programming also do well in OOP?
# - Are mathematical and probabilistic skills correlated?
# - Which subjects are independent?
#
# A **heatmap** will help visualize these correlations.

# %%
numeric_cols = [
    'Proba_Stat',               
    'Analyse_Numerique',        
    'C++',                      
    'Architecture_des_systèmes_à_Microprocesseu',  
    'Base_de_Données',         
    'Technologies_Web ',       
    'Analyse_et_conception_des_Systèmes_dInformation'  
]
df_numeric = df[numeric_cols]

# %%
corr_matrix = df_numeric.corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(
    corr_matrix,
    annot=True,      
    cmap='coolwarm', #
    vmin=-1,         
    vmax=1,          
    linewidths=0.5,
    fmt=".2f"        
)
plt.title("Correlation Between Subjects", fontsize=16)
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Select target (what we want to predict) - let's use 'Proba_Stat' as an example
target = 'Proba_Stat'

# Select features (other subjects) - exclude non-grade columns and the target
features = [col for col in df.columns if col not in ['Student_ID', 'Last_Name', 'First_Name', target]]

# Create feature matrix (X) and target vector (y)
X = df[features]
y = df[target]

# %%
X
# Out:
#      Unnamed: 0    0  Analyse_Numerique  Structure_Donnee   C++  \
# 0             0    1              11.50             11.50  16.0
# 1             1    2               9.00             15.00  19.5
# 2             2    3               2.75              8.00  13.5
# 3             3    4               7.00              7.50  10.5
# 4             4    5               4.00              7.25  17.5
# ..          ...  ...                ...               ...   ...
# 103         103  104              11.50              9.50   8.5
# 104         104  105              12.00             10.00  10.0
# 105         105  106              14.00              9.25  11.5
# 106         106  107              10.00             14.50  15.5
# 107         107  108               0.00              0.00   0.0
#
#      Architecture_des_systèmes_à_Microprocesseu  Fondement_des_réseau  \
# 0                                         12.50                  9.50
# ...

# %%
y
# Out:
# 0       8.00
# 1      12.50
# 2       9.00
# 3       9.00
# 4       4.75
#        ...
# 103    13.25
# 104     9.75
# 105    12.25
# 106    14.25
# 107     0.00
# Name: Proba_Stat, Length: 108, dtype: float64

# %%
# Split data into 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# Create and train the model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on test set
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared Score: {r2:.2f}")
# Out:
# Mean Squared Error: 5.04
# R-squared Score: 0.20

# %%
coefficients = pd.DataFrame({
    'Feature': features,
    'Coefficient': model.coef_
}).sort_values('Coefficient', ascending=False)

print("\nFeature Coefficients:")
print(coefficients)
# Out:
# Feature Coefficients:
#                                             Feature  Coefficient
# 2                                 Analyse_Numerique     0.246067
# 9   Analyse_et_conception_des_Systèmes_dInformation     0.196039
# 6                              Fondement_des_réseau     0.151997
# 8                                   Base_de_Données     0.117335
# 4                                               C++     0.112094
# 5        Architecture_des_systèmes_à_Microprocesseu     0.050450
# 1                                                 0     0.015701
# 0                                        Unnamed: 0     0.015701
# 12                        Culture_et_Communication     -0.013571
# 3                                  Structure_Donnee    -0.024285
# 7                                 Technologies_Web     -0.035271
# 10                        Théorie_des_Organisations    -0.036266
# 11                             Professional_English    -0.060316

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)  # Perfect prediction line
plt.xlabel('Actual Grades')
plt.ylabel('Predicted Grades')
plt.title(f'Actual vs Predicted {target} Grades')
plt.show()

# %%
# Find Idriss Haddad's grades (replace 'IDRISS_HADDAD_ID' with his actual Student_ID if needed)
idriss_data = df[df['Last_Name'].str.upper() == 'HADDAD']  # Case-insensitive search
print(idriss_data)
# Out:
#     Unnamed: 0   0  Student_ID Last_Name First_Name  Proba_Stat  \
# 93          93  94    11454180    HADDAD     IDRISS        14.5
#
#     Analyse_Numerique  Structure_Donnee   C++  \
# 93               15.0              10.5  10.5
#
#     Architecture_des_systèmes_à_Microprocesseu  Fondement_des_réseau  \
# 93                                         7.0                  8.75
#
#     Technologies_Web   Base_de_Données  \
# 93               19.0              7.5
#
#     Analyse_et_conception_des_Systèmes_dInformation  \
# 93                                              3.5
#
#     Théorie_des_Organisations  Professional_English  Culture_et_Communication
# 93                        4.0                  12.5                       14.5

# %%
# Features (other subjects) - exclude non-grade columns and 'Proba_Stat'
features = [col for col in df.columns if col not in ['Student_ID', 'Last_Name', 'First_Name', 'Proba_Stat']]

# Extract Idriss's grades for prediction
X_idriss = idriss_data[features]

# %%
X_idriss
# Out:
#     Unnamed: 0   0  Analyse_Numerique  Structure_Donnee   C++  \
# 93          93  94               15.0              10.5  10.5
#
#     Architecture_des_systèmes_à_Microprocesseu  Fondement_des_réseau  \
# 93                                         7.0                  8.75
#
#     Technologies_Web   Base_de_Données  \
# 93               19.0              7.5
#
#     Analyse_et_conception_des_Systèmes_dInformation  \
# 93                                              3.5
#
#     Théorie_des_Organisations  Professional_English  Culture_et_Communication
# 93                        4.0                  12.5                       14.5

# %%
# Use your trained linear regression model
predicted_grade = model.predict(X_idriss)

print(f"Predicted Proba_Stat grade for Idriss Haddad: {predicted_grade[0]:.1f}/20")
# Out:
# Predicted Proba_Stat grade for Idriss Haddad: 10.3/20

# %%
actual_grade = idriss_data['Proba_Stat'].values[0]
print(f"Actual Proba_Stat grade: {actual_grade:.1f}/20")
print(f"Prediction Error: {abs(predicted_grade[0] - actual_grade):.1f} points")
# Out:
# Actual Proba_Stat grade: 14.5/20
# Prediction Error: 4.2 points

# %%
# Show feature coefficients (from your trained model)
coefficients = pd.DataFrame({
    'Subject': features,
    'Impact_on_Proba_Stat': model.coef_
}).sort_values('Impact_on_Proba_Stat', ascending=False)

print("\nSubjects Most Influencing Proba_Stat Prediction:")
print(coefficients)
# Out:
# Subjects Most Influencing Proba_Stat Prediction:
#                                             Subject  Impact_on_Proba_Stat
# 2                                 Analyse_Numerique              0.246067
# 9   Analyse_et_conception_des_Systèmes_dInformation              0.196039
# 6                              Fondement_des_réseau              0.151997
# 8                                   Base_de_Données              0.117335
# 4                                               C++              0.112094
# 5        Architecture_des_systèmes_à_Microprocesseu              0.050450
# 1                                                 0              0.015701
# 0                                        Unnamed: 0              0.015701
# 12                        Culture_et_Communication              -0.013571
# 3                                  Structure_Donnee             -0.024285
# 7                                 Technologies_Web              -0.035271
# ...
